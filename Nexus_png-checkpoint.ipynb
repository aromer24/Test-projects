# %%
#Importing libraries
# !pip install Pytesseract
# !pip install tesseract
# Out:
# Requirement already satisfied: Pytesseract in c:\users\arome\appdata\local\programs\python\python39\lib\site-packages (0.3.8)
# Requirement already satisfied: Pillow in c:\users\arome\appdata\local\programs\python\python39\lib\site-packages (from Pytesseract) (8.3.1)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\arome\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tesseract in c:\users\arome\appdata\local\programs\python\python39\lib\site-packages (0.1.3)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\arome\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\arome\appdata\local\programs\python\python39\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\arome\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.21.2)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\arome\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import pytesseract
import numpy as np

# %%
#Loading image using OpenCV
img = cv2.imread(r'/Users/arome/Downloads/Coding test/2020 - Coding test/samples/test_scan.jpg')

# %%
from PIL import Image
path = '/Users/arome/Downloads/Coding test/2020 - Coding test/samples/test_scan.jpg'
display(Image.open(path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1913x2449 at 0x1903622CFA0>

# %%
#Preprocessing image
#Converting to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#creating Binary image by selecting proper threshold
binary_image = cv2.threshold(gray_image ,130,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# %%
#Inverting the image
inverted_bin = cv2.bitwise_not(binary_image)

# %%
#Some noise reduction
kernel = np.ones((2,2),np.uint8)
processed_img = cv2.erode(inverted_bin, kernel, iterations = 1)
processed_img = cv2.dilate(processed_img, kernel, iterations = 1)

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
#Applying image_to_string method
text = pytesseract.image_to_string(processed_img)

# %%
print(text)
# Out:
# @@ BRITISH
# @@ COUNCIL
#
# Questions 36—40
# Complete the summary below.
#
# Choose NO MORE THAN TWO WORDS from the passage for each answer.
#
# Write your answers in boxes 36-40 on your answer sheet.
#
# Sobotka argues that big business and users of helium need to help look after helium
# stocks because 36 ............cecseeee will not be encouraged through buying and selling
# alone. Richardson believes that the 37 ...........cccssse0 needs to be withdrawn, as the
#
# U.S. pravides most of the world’s helium. He argues that higher costs would mean
#
# fer=te)e)(-Mar=Wi-)
# 1: ee to use the resource many times over.
#
# People should need a 39 ...........ecceee ee to access helium that we still have.
# Furthermore, 2 40 ........cccceceneees should ensure that helium is used carefully.
#
# 14
